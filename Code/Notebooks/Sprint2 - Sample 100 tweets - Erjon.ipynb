# %%
import pandas as pd
import json
from pandas import json_normalize
import numpy as np

# Define the relative path to the JSON file
file_path = r'..\..\Data\Raw\tweets_ws23_v1.json'

# Load json file
with open(file_path, 'r', encoding='utf-8') as json_file:
    json_data = json.load(json_file)

# %%
def get_all_keys(obj):
    keys = set()
    if isinstance(obj, dict):
        keys.update(obj.keys())
        for value in obj.values():
            keys.update(get_all_keys(value))
    elif isinstance(obj, list):
        for item in obj:
            keys.update(get_all_keys(item))
    return keys

# Get all unique keys
all_keys = get_all_keys(json_data)

# Convert the set to a list to see all unique keys
all_keys_list = list(all_keys)

# %%
def flatten_json(y):
    """Flatten a nested JSON object"""
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# Flatten the JSON data
flattened_data = [flatten_json(entry) for entry in json_data]

# Convert the list of flattened dictionaries to a DataFrame
df = pd.DataFrame(flattened_data)

# Show the DataFrame
df
# Out:
#                 source_created_at           author_id  \
# 0      2020-09-18 21:56:20.798000           593731316
# 1      2020-10-13 07:31:53.122000  745583289520496640
# 2      2020-10-26 19:27:24.695000           303134761
# 3      2020-10-26 19:28:49.281000           303134761
# 4      2020-09-28 11:59:41.212000            56427671
# ...                           ...                 ...
# 16944         2019-07-11 07:34:35            24940900
# 16945  2020-08-10 11:19:10.181000            63559912
# 16946  2020-08-29 09:51:10.833000           277455263
# 16947  2020-11-02 12:06:06.967000          3050957613
# 16948  2020-11-02 12:06:06.967000          3050957613
#
#                                                     text      source language  \
# 0      @DSisourath The Thameslink core between London...    sprinklr       en
# 1      @DulwichHistory Loving the complaint about peo...    sprinklr       en
# 2      @SW_Help .And yet you have no toilets on some ...    sprinklr       en
# 3      @SW_Help you have no toilets on some of your t...    sprinklr       en
# 4      @SpeedySticks007 @MrNeilJH @TLRailUK @christia...    sprinklr       en
# ...                                                  ...         ...      ...
# 16944  Haha oh man the audio corruption on @TLRailUK ...  brandwatch    en-GB
# 16945  @TLRailUK SweetIs there a plug to charge my ph...    sprinklr       en
# 16946  @TLRailUK now there are far fewer commuters ha...    sprinklr       en
# 16947  @geofftech I am voting for Thameslink. 1. in a...    sprinklr       en
# 16948  @geofftech I am voting for Thameslink. 1. in a...    sprinklr       en
#
#        longitude  latitude                                    id  \
# 0       -0.12574  51.50853  acd7673f-e621-5f1a-d662-df278964a6ea
# 1       -0.12574  51.50853  5b92aba8-4b05-6c63-8485-e9c870742137
# 2       -0.12574  51.50853  0a799c07-8b76-17ba-b840-e538d51e832d
# 3       -0.12574  51.50853  8b4d2a34-c4f0-0e19-4055-dfe4af5f0e14
# 4       -1.09125  50.79899  1fd08862-d8c7-0682-6b11-2603fba22d94
# ...          ...       ...                                   ...
# 16944        NaN       NaN  b47948df-1732-7021-ee77-238f839a2ea0
# 16945   -0.12574  51.50853  bcb3a01a-e58c-e082-3111-10fa77d1a9f7
# 16946   -0.12574  51.50853  f440c7e6-9e2d-31c4-3626-b9d8288cbbe3
# 16947   -0.12574  51.50853  859ab156-cad3-3bf0-4b6d-de494b483501
# 16948   -0.12574  51.50853  859ab156-cad3-3bf0-4b6d-de494b483501
#
#                     labels_topic_0_tweet_id labels_topic_0_user_id  \
# 0      acd7673f-e621-5f1a-d662-df278964a6ea               Z003XDCS
# 1      5b92aba8-4b05-6c63-8485-e9c870742137               Z003XDCS
# 2      0a799c07-8b76-17ba-b840-e538d51e832d               Z003XDCS
# 3      8b4d2a34-c4f0-0e19-4055-dfe4af5f0e14               Z003XDCS
# 4      1fd08862-d8c7-0682-6b11-2603fba22d94               Z003XDCS
# ...                                     ...                    ...
# 16944  b47948df-1732-7021-ee77-238f839a2ea0               Z003XDCS
# 16945  bcb3a01a-e58c-e082-3111-10fa77d1a9f7               Z003XDCS
# 16946  f440c7e6-9e2d-31c4-3626-b9d8288cbbe3               Z003XDCS
# 16947  859ab156-cad3-3bf0-4b6d-de494b483501               Z003XDCS
# 16948  859ab156-cad3-3bf0-4b6d-de494b483501               Z003XDCS
#
#        labels_topic_0_relevant labels_topic_0_topic  \
# 0                         True              service
# 1                         True               delays
# 2                         True              toilets
# 3                         True              toilets
# 4                         True                seats
# ...                        ...                  ...
# 16944                     True        announcements
# 16945                     True                plugs
# 16946                     True               tables
# 16947                     True              toilets
# 16948                     True        announcements
#
#        labels_topic_0_ground_truth                     labels_topic_0_id  \
# 0                             True  8655353b-cc71-1e89-95d5-1c4e6bf200e1
# 1                             True  8aee5c86-6e93-24d4-6d9d-d8a9f2f19cef
# 2                             True  2d54f18a-442d-b59b-9daf-0490dc64d21a
# 3                             True  01db4b72-b21c-60f9-b627-5a47df56655a
# 4                             True  4fe5177f-8347-1726-c2e9-cc183f16d5b1
# ...                            ...                                   ...
# 16944                         True  aca953e8-bec4-216a-5a6e-e3530e420fa9
# 16945                         True  e170272d-5e5c-6ce7-ba7c-748aa56073d7
# 16946                         True  356eb822-07b7-ca2d-0087-56284ce2e95b
# 16947                         True  3f6f4be1-37c7-17cb-56c3-2e91b0ae237a
# 16948                         True  3318b20f-5417-1c56-f12b-86c6df2e376e
#
#                 labels_sentiment_0_tweet_id labels_sentiment_0_user_id  \
# 0      acd7673f-e621-5f1a-d662-df278964a6ea                   Z003XDCS
# 1      5b92aba8-4b05-6c63-8485-e9c870742137                   Z003XDCS
# 2      0a799c07-8b76-17ba-b840-e538d51e832d                   Z003XDCS
# 3      8b4d2a34-c4f0-0e19-4055-dfe4af5f0e14                   Z003XDCS
# 4      1fd08862-d8c7-0682-6b11-2603fba22d94                   Z003XDCS
# ...                                     ...                        ...
# 16944  b47948df-1732-7021-ee77-238f839a2ea0                   Z003XDCS
# 16945  bcb3a01a-e58c-e082-3111-10fa77d1a9f7                   Z003XDCS
# 16946  f440c7e6-9e2d-31c4-3626-b9d8288cbbe3                   Z003XDCS
# 16947  859ab156-cad3-3bf0-4b6d-de494b483501                   Z003XDCS
# 16948  859ab156-cad3-3bf0-4b6d-de494b483501                   Z003XDCS
#
#       labels_sentiment_0_sentiment  labels_sentiment_0_ground_truth  \
# 0                         negative                             True
# 1                         negative                             True
# 2                         negative                             True
# 3                         negative                             True
# 4                          neutral                             True
# ...                            ...                              ...
# 16944                      neutral                             True
# 16945                      neutral                             True
# 16946                      neutral                             True
# 16947                      neutral                             True
# 16948                      neutral                             True
#
#                       labels_sentiment_0_id            source_id
# 0      5ee4d218-65a9-70a0-0964-a5b00e594a41                  NaN
# 1      2f8d741f-59cf-d1ab-27f9-5537a9718f94                  NaN
# 2      be479c30-17c3-220f-8eae-eaf6fc874431                  NaN
# 3      6df4ba5c-952f-732f-2a7e-4cc6f7d56f61                  NaN
# 4      e5aa618a-c554-6bdb-cb5b-bcdadcaa4e98                  NaN
# ...                                     ...                  ...
# 16944  be02e403-49c2-e366-3324-09f1696ce526  1149220424313708544
# 16945  a0c0e79c-11ee-4700-45b2-dcf7234f0a10                  NaN
# 16946  786bb503-8ec0-6a21-ea3f-6995ceb7e3e0                  NaN
# 16947  399d6906-75db-1150-0f34-414c6cf917cf                  NaN
# 16948  399d6906-75db-1150-0f34-414c6cf917cf                  NaN
#
# [16949 rows x 20 columns]

# %%
df[df['labels_sentiment_0_sentiment']=='positive']
# Out:
#                 source_created_at               author_id  \
# 17     2020-09-06 18:46:23.363000                20998602
# 2314          2019-03-13 17:43:18   8.619800622031626e+17
# 2315          2019-03-19 09:06:35  1.1037275362683453e+18
# 2501          2019-05-20 13:42:01   7.427586006706463e+17
# 2680   2020-08-14 17:53:58.404000     1073559509644296192
# ...                           ...                     ...
# 16884  2020-11-24 18:30:00.665000              2589687589
# 16885  2020-11-24 18:30:00.336000              2589703207
# 16886  2020-11-24 18:00:00.368000              2589687589
# 16927  2020-11-03 23:10:35.031000     1079461854467055616
# 16932  2020-11-03 14:38:20.038000     1118188172373037056
#
#                                                     text      source language  \
# 17     I love this train conductor(?), he's apologise...    sprinklr       en
# 2314   2,000 more Thameslink seats for Cambridge and ...  brandwatch    en-GB
# 2315   2,000 more Thameslink seats for Cambridge and ...  brandwatch       en
# 2501   4 @TLRailUK trains a hour from London Bridge t...  brandwatch    en-GB
# 2680   @BTPCambs @TLRailUK Thank you @btpcambs. Glad ...    sprinklr       en
# ...                                                  ...         ...      ...
# 16884  We’re proud to announce our partnership with @...    sprinklr       en
# 16885  We’re proud to announce our partnership with @...    sprinklr       en
# 16886  We’re proud to announce our partnership with @...    sprinklr       en
# 16927  @geofftech @TLRailUK has much better trains th...    sprinklr       en
# 16932  @geofftech My vote goes to @TLRailUK. Spacious...    sprinklr       en
#
#        longitude  latitude                                    id  \
# 17      -0.70312  52.16045  d7d4596f-34ed-910a-462a-c4bc8143b968
# 2314         NaN       NaN  d8d7d2d9-3f44-1a6a-a004-b71bda46c067
# 2315         NaN       NaN  2c4ba00d-2ae5-715c-f014-91d85392d88b
# 2501         NaN       NaN  b3b1ec9f-2fee-5ec6-e971-41784aae424a
# 2680    -0.70312  52.16045  0c09958c-9026-67c8-c58a-82bc29c1c8c0
# ...          ...       ...                                   ...
# 16884   -2.69531  54.75844  42022b95-c011-f4a1-5783-d5fc46edbaf9
# 16885   -2.69531  54.75844  e6500ec3-ee46-3d4c-477b-c3605cf85147
# 16886   -2.69531  54.75844  6e3e7746-1987-8474-ee5d-819dacebd846
# 16927    1.29834  52.62783  82a30c30-e154-2a5c-ca5b-591f4089d928
# 16932   -0.70312  52.16045  707f6f9c-1ebf-7d22-6f4a-49ce85960454
#
#                     labels_topic_0_tweet_id labels_topic_0_user_id  \
# 17     d7d4596f-34ed-910a-462a-c4bc8143b968               Z003XDCS
# 2314   d8d7d2d9-3f44-1a6a-a004-b71bda46c067               Z003XDCS
# 2315   2c4ba00d-2ae5-715c-f014-91d85392d88b               Z003XDCS
# 2501   b3b1ec9f-2fee-5ec6-e971-41784aae424a               Z003XDCS
# 2680   0c09958c-9026-67c8-c58a-82bc29c1c8c0               Z003XDCS
# ...                                     ...                    ...
# 16884  42022b95-c011-f4a1-5783-d5fc46edbaf9               Z003XDCS
# 16885  e6500ec3-ee46-3d4c-477b-c3605cf85147               Z003XDCS
# 16886  6e3e7746-1987-8474-ee5d-819dacebd846               Z003XDCS
# 16927  82a30c30-e154-2a5c-ca5b-591f4089d928               Z003XDCS
# 16932  707f6f9c-1ebf-7d22-6f4a-49ce85960454               Z003XDCS
#
#        labels_topic_0_relevant labels_topic_0_topic  \
# 17                        True              service
# 2314                      True        train_general
# 2315                      True        train_general
# 2501                      True                seats
# 2680                      True                covid
# ...                        ...                  ...
# 16884                     True              station
# 16885                     True              station
# 16886                     True              station
# 16927                     True                noise
# 16932                     True     air conditioning
#
#        labels_topic_0_ground_truth                     labels_topic_0_id  \
# 17                            True  e0157ff4-2379-a3ae-8a5c-333e9ce2b18d
# 2314                          True  f658b34f-f26c-3f7b-de44-47d1381598aa
# 2315                          True  bc49eccb-592c-6103-0ab6-fd900e329b4e
# 2501                          True  1a4c83f9-a7d9-9c09-8678-bb1ff5fe8d94
# 2680                          True  f51ec841-c965-0563-fb1a-e5db3e21585f
# ...                            ...                                   ...
# 16884                         True  7b7034d0-230d-9801-054c-4d9c0a83c4cf
# 16885                         True  2bc449eb-fc0c-4369-d730-09c71d73b004
# 16886                         True  ab73d1e4-af6d-c3ec-c505-f42bbdad95ab
# 16927                         True  649399f0-2755-17a8-e187-9ba50f008faf
# 16932                         True  0d75607a-d7c3-c235-55cb-7bf1d2695aac
#
#                 labels_sentiment_0_tweet_id labels_sentiment_0_user_id  \
# 17     d7d4596f-34ed-910a-462a-c4bc8143b968                   Z003XDCS
# 2314   d8d7d2d9-3f44-1a6a-a004-b71bda46c067                   Z003XDCS
# 2315   2c4ba00d-2ae5-715c-f014-91d85392d88b                   Z003XDCS
# 2501   b3b1ec9f-2fee-5ec6-e971-41784aae424a                   Z003XDCS
# 2680   0c09958c-9026-67c8-c58a-82bc29c1c8c0                   Z003XDCS
# ...                                     ...                        ...
# 16884  42022b95-c011-f4a1-5783-d5fc46edbaf9                   Z003XDCS
# 16885  e6500ec3-ee46-3d4c-477b-c3605cf85147                   Z003XDCS
# 16886  6e3e7746-1987-8474-ee5d-819dacebd846                   Z003XDCS
# 16927  82a30c30-e154-2a5c-ca5b-591f4089d928                   Z003XDCS
# 16932  707f6f9c-1ebf-7d22-6f4a-49ce85960454                   Z003XDCS
#
#       labels_sentiment_0_sentiment  labels_sentiment_0_ground_truth  \
# 17                        positive                             True
# 2314                      positive                             True
# 2315                      positive                             True
# 2501                      positive                             True
# 2680                      positive                             True
# ...                            ...                              ...
# 16884                     positive                             True
# 16885                     positive                             True
# 16886                     positive                             True
# 16927                     positive                             True
# 16932                     positive                             True
#
#                       labels_sentiment_0_id            source_id
# 17     19beeb3e-ad24-30f1-64b7-08b327579f40                  NaN
# 2314   6f7441d2-7107-f40c-cc2b-50a694d0a20f  1105887070407536641
# 2315   48e68791-2f8b-182d-00ae-86727b11dd9c  1107931359564177408
# 2501   5a662bfa-0b25-da34-f2aa-956f1c875178  1130468725776363528
# 2680   5557f475-0f82-d8de-16ab-093d78efb310                  NaN
# ...                                     ...                  ...
# 16884  a127f37c-49b6-0e86-7cdf-53733951c0bf                  NaN
# 16885  da1fd8eb-0eef-d69d-bc66-38271a116d7d                  NaN
# 16886  76622c39-b342-c468-7435-845cea76c4a1                  NaN
# 16927  9b5f3b6f-961d-0fd8-4c4e-baeb35e963b2                  NaN
# 16932  2dbd4e06-ee18-9dcc-8b5a-18864c5e52ca                  NaN
#
# [242 rows x 20 columns]

# %%
np.random.seed(42)

df_sample = df['text',].sample(n=100)
df_sample.to_csv(r'..\..\Data\Processed\sample_tweets.csv', index=False)

# %%
df_sample
# Out:
# 8062     @TLRailUK You opened the doors 20 seconds afte...
# 16105    @TLRailUK why don’t the doors open at every st...
# 7838     @TLRailUK When on phone to @LNER they said as ...
# 3484     @LiveCommute @bus131 @tlupdates @TLRailUK @bri...
# 9618     @TLRailUK what is going on with the 17:11 from...
#                                ...
# 2299     1949 Thameslink train to Brighton: Delayed - p...
# 1767     1012 Thameslink train to Cambridge: Delayed - ...
# 13361    TRAVEL: 15 minute delays on @SouthernRailUK @T...
# 7828     @TLRailUK What’s happening?? Driver hasn’t giv...
# 12048    Evening @tlrailuk - you cancel the 1724 ZFD to...
# Name: text, Length: 100, dtype: object
